# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %% [markdown]
# # Summary

# %% [markdown]
# Write a short summary of the process and results here.

# %%
pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (3.3.2)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: requests>=2.27.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.32.3)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.12.3)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.1.5)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.0.2)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (4.66.5)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (8.5.0)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: pandas<2.2.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (8.1.5)
# Requirement already satisfied: schemdraw==0.15 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: sktime==0.26.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: jinja2>=3 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (3.1.4)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (4.5.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.14.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: numba>=0.55.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.60.0)
# Requirement already satisfied: xxhash in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (8.18.1)
# Requirement already satisfied: cloudpickle in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (3.0.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: packaging in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from sktime==0.26.0->pycaret) (24.1)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.20.2)
# Requirement already satisfied: typing-extensions in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.5.0->pycaret) (4.12.2)
# Requirement already satisfied: colorama in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: stack-data in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: matplotlib-inline in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: decorator in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: traitlets>=5 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.5.0->pycaret) (2.18.0)
# Requirement already satisfied: exceptiongroup in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.5.0->pycaret) (1.2.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.48)
# Requirement already satisfied: comm>=0.1.3 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.13)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.1.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (10.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (6.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.54.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.35.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (24.2.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.20.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.12.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (306)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from numba>=0.55.0->pycaret) (0.43.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pandas<2.2.0->pycaret) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pandas<2.2.0->pycaret) (2024.2)
# Requirement already satisfied: six in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from plotly>=5.14.0->pycaret) (9.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.7)
# Requirement already satisfied: dash>=2.9.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.18.1)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: nest-asyncio in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: retrying in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: setuptools in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (56.0.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.4)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.8.2)
# Requirement already satisfied: urllib3 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.2.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.11)
# Requirement already satisfied: wcwidth in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.27.1->pycaret) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.27.1->pycaret) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.27.1->pycaret) (2024.8.30)
# Requirement already satisfied: pure-eval in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\barsha\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.4.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\Barsha\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
from pycaret.classification import *

# Load the data
churn_data = pd.read_csv('churn_data.csv')

# Initialize PyCaret classification setup
clf = setup(data=churn_data, target='Churn', session_id=42)
# Out:
# <style type="text/css">
# #T_01515_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_01515">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01515_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_01515_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01515_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01515_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_01515_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_01515_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_01515_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_01515_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_01515_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_01515_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_01515_row3_col1" class="data row3 col1" >No: 0, Yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_01515_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_01515_row4_col1" class="data row4 col1" >(7043, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_01515_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_01515_row5_col1" class="data row5 col1" >(7043, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_01515_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_01515_row6_col1" class="data row6 col1" >(4930, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_01515_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_01515_row7_col1" class="data row7 col1" >(2113, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_01515_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_01515_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_01515_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_01515_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_01515_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_01515_row10_col1" class="data row10 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_01515_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_01515_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_01515_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_01515_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_01515_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_01515_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_01515_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_01515_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_01515_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_01515_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_01515_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_01515_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_01515_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_01515_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_01515_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_01515_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_01515_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_01515_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_01515_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_01515_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_01515_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_01515_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_01515_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_01515_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_01515_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_01515_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_01515_row23_col1" class="data row23 col1" >8173</td>
#     </tr>
#   </tbody>
# </table>

# %%
churn_data = pd.read_csv('churn_data.csv')
print(churn_data.head())
# Out:
#    customerID  tenure PhoneService        Contract              PaymentMethod  \
# 0  7590-VHVEG       1           No  Month-to-month           Electronic check
# 1  5575-GNVDE      34          Yes        One year               Mailed check
# 2  3668-QPYBK       2          Yes  Month-to-month               Mailed check
# 3  7795-CFOCW      45           No        One year  Bank transfer (automatic)
# 4  9237-HQITU       2          Yes  Month-to-month           Electronic check
#
#    MonthlyCharges  TotalCharges Churn
# 0           29.85         29.85    No
# 1           56.95       1889.50    No
# 2           53.85        108.15   Yes
# 3           42.30       1840.75    No
# 4           70.70        151.65   Yes

# %%
print(churn_data.columns)
# Out:
# Index(['customerID', 'tenure', 'PhoneService', 'Contract', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
best_model = compare_models(sort='AUC')
# Out:
# <style type="text/css">
# #T_c2a62 th {
#   text-align: left;
# }
# #T_c2a62_row0_col0, #T_c2a62_row0_col1, #T_c2a62_row0_col3, #T_c2a62_row0_col4, #T_c2a62_row0_col5, #T_c2a62_row0_col6, #T_c2a62_row0_col7, #T_c2a62_row1_col0, #T_c2a62_row1_col1, #T_c2a62_row1_col2, #T_c2a62_row1_col3, #T_c2a62_row1_col4, #T_c2a62_row1_col5, #T_c2a62_row1_col6, #T_c2a62_row1_col7, #T_c2a62_row2_col0, #T_c2a62_row2_col1, #T_c2a62_row2_col2, #T_c2a62_row2_col3, #T_c2a62_row2_col5, #T_c2a62_row3_col0, #T_c2a62_row3_col2, #T_c2a62_row3_col4, #T_c2a62_row3_col6, #T_c2a62_row3_col7, #T_c2a62_row4_col0, #T_c2a62_row4_col1, #T_c2a62_row4_col2, #T_c2a62_row4_col3, #T_c2a62_row4_col4, #T_c2a62_row4_col5, #T_c2a62_row4_col6, #T_c2a62_row4_col7, #T_c2a62_row5_col0, #T_c2a62_row5_col1, #T_c2a62_row5_col2, #T_c2a62_row5_col3, #T_c2a62_row5_col4, #T_c2a62_row5_col5, #T_c2a62_row5_col6, #T_c2a62_row5_col7, #T_c2a62_row6_col0, #T_c2a62_row6_col1, #T_c2a62_row6_col2, #T_c2a62_row6_col3, #T_c2a62_row6_col4, #T_c2a62_row6_col5, #T_c2a62_row6_col6, #T_c2a62_row6_col7, #T_c2a62_row7_col0, #T_c2a62_row7_col1, #T_c2a62_row7_col2, #T_c2a62_row7_col3, #T_c2a62_row7_col4, #T_c2a62_row7_col5, #T_c2a62_row7_col6, #T_c2a62_row7_col7, #T_c2a62_row8_col0, #T_c2a62_row8_col1, #T_c2a62_row8_col2, #T_c2a62_row8_col3, #T_c2a62_row8_col4, #T_c2a62_row8_col5, #T_c2a62_row8_col6, #T_c2a62_row8_col7, #T_c2a62_row9_col0, #T_c2a62_row9_col1, #T_c2a62_row9_col2, #T_c2a62_row9_col3, #T_c2a62_row9_col4, #T_c2a62_row9_col5, #T_c2a62_row9_col6, #T_c2a62_row9_col7, #T_c2a62_row10_col0, #T_c2a62_row10_col1, #T_c2a62_row10_col2, #T_c2a62_row10_col3, #T_c2a62_row10_col4, #T_c2a62_row10_col5, #T_c2a62_row10_col6, #T_c2a62_row10_col7, #T_c2a62_row11_col0, #T_c2a62_row11_col1, #T_c2a62_row11_col2, #T_c2a62_row11_col3, #T_c2a62_row11_col4, #T_c2a62_row11_col5, #T_c2a62_row11_col6, #T_c2a62_row11_col7, #T_c2a62_row12_col0, #T_c2a62_row12_col1, #T_c2a62_row12_col2, #T_c2a62_row12_col3, #T_c2a62_row12_col4, #T_c2a62_row12_col5, #T_c2a62_row12_col6, #T_c2a62_row12_col7, #T_c2a62_row13_col0, #T_c2a62_row13_col1, #T_c2a62_row13_col2, #T_c2a62_row13_col3, #T_c2a62_row13_col4, #T_c2a62_row13_col5, #T_c2a62_row13_col6, #T_c2a62_row13_col7 {
#   text-align: left;
# }
# #T_c2a62_row0_col2, #T_c2a62_row2_col4, #T_c2a62_row2_col6, #T_c2a62_row2_col7, #T_c2a62_row3_col1, #T_c2a62_row3_col3, #T_c2a62_row3_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c2a62_row0_col8, #T_c2a62_row1_col8, #T_c2a62_row2_col8, #T_c2a62_row3_col8, #T_c2a62_row4_col8, #T_c2a62_row5_col8, #T_c2a62_row6_col8, #T_c2a62_row7_col8, #T_c2a62_row8_col8, #T_c2a62_row9_col8, #T_c2a62_row10_col8, #T_c2a62_row11_col8, #T_c2a62_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c2a62_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c2a62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2a62_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c2a62_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c2a62_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_c2a62_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c2a62_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_c2a62_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_c2a62_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_c2a62_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_c2a62_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2a62_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_c2a62_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_c2a62_row0_col1" class="data row0 col1" >0.7343</td>
#       <td id="T_c2a62_row0_col2" class="data row0 col2" >0.8356</td>
#       <td id="T_c2a62_row0_col3" class="data row0 col3" >0.7343</td>
#       <td id="T_c2a62_row0_col4" class="data row0 col4" >0.5397</td>
#       <td id="T_c2a62_row0_col5" class="data row0 col5" >0.6221</td>
#       <td id="T_c2a62_row0_col6" class="data row0 col6" >-0.0008</td>
#       <td id="T_c2a62_row0_col7" class="data row0 col7" >-0.0054</td>
#       <td id="T_c2a62_row0_col8" class="data row0 col8" >0.5970</td>
#     </tr>
#     <tr>
#       <th id="T_c2a62_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_c2a62_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_c2a62_row1_col1" class="data row1 col1" >0.7347</td>
#       <td id="T_c2a62_row1_col2" class="data row1 col2" >0.8258</td>
#       <td id="T_c2a62_row1_col3" class="data row1 col3" >0.7347</td>
#       <td id="T_c2a62_row1_col4" class="data row1 col4" >0.5398</td>
#       <td id="T_c2a62_row1_col5" class="data row1 col5" >0.6223</td>
#       <td id="T_c2a62_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_c2a62_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_c2a62_row1_col8" class="data row1 col8" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_c2a62_level0_row2" class="row_heading level0 row2" >nb</th>
#       <td id="T_c2a62_row2_col0" class="data row2 col0" >Naive Bayes</td>
#       <td id="T_c2a62_row2_col1" class="data row2 col1" >0.7142</td>
#       <td id="T_c2a62_row2_col2" class="data row2 col2" >0.8112</td>
#       <td id="T_c2a62_row2_col3" class="data row2 col3" >0.7142</td>
#       <td id="T_c2a62_row2_col4" class="data row2 col4" >0.7874</td>
#       <td id="T_c2a62_row2_col5" class="data row2 col5" >0.7301</td>
#       <td id="T_c2a62_row2_col6" class="data row2 col6" >0.3934</td>
#       <td id="T_c2a62_row2_col7" class="data row2 col7" >0.4228</td>
#       <td id="T_c2a62_row2_col8" class="data row2 col8" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_c2a62_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_c2a62_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_c2a62_row3_col1" class="data row3 col1" >0.7594</td>
#       <td id="T_c2a62_row3_col2" class="data row3 col2" >0.7337</td>
#       <td id="T_c2a62_row3_col3" class="data row3 col3" >0.7594</td>
#       <td id="T_c2a62_row3_col4" class="data row3 col4" >0.7429</td>
#       <td id="T_c2a62_row3_col5" class="data row3 col5" >0.7470</td>
#       <td id="T_c2a62_row3_col6" class="data row3 col6" >0.3279</td>
#       <td id="T_c2a62_row3_col7" class="data row3 col7" >0.3341</td>
#       <td id="T_c2a62_row3_col8" class="data row3 col8" >0.3320</td>
#     </tr>
#     <tr>
#       <th id="T_c2a62_level0_row4" class="row_heading level0 row4" >svm</th>
#       <td id="T_c2a62_row4_col0" class="data row4 col0" >SVM - Linear Kernel</td>
#       <td id="T_c2a62_row4_col1" class="data row4 col1" >0.6513</td>
#       <td id="T_c2a62_row4_col2" class="data row4 col2" >0.6551</td>
#       <td id="T_c2a62_row4_col3" class="data row4 col3" >0.6513</td>
#       <td id="T_c2a62_row4_col4" class="data row4 col4" >0.7669</td>
#       <td id="T_c2a62_row4_col5" class="data row4 col5" >0.6236</td>
#       <td id="T_c2a62_row4_col6" class="data row4 col6" >0.2481</td>
#       <td id="T_c2a62_row4_col7" class="data row4 col7" >0.3028</td>
#       <td id="T_c2a62_row4_col8" class="data row4 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_c2a62_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_c2a62_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_c2a62_row5_col1" class="data row5 col1" >0.7347</td>
#       <td id="T_c2a62_row5_col2" class="data row5 col2" >0.6431</td>
#       <td id="T_c2a62_row5_col3" class="data row5 col3" >0.7347</td>
#       <td id="T_c2a62_row5_col4" class="data row5 col4" >0.5398</td>
#       <td id="T_c2a62_row5_col5" class="data row5 col5" >0.6223</td>
#       <td id="T_c2a62_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_c2a62_row5_col7" class="data row5 col7" >0.0000</td>
#       <td id="T_c2a62_row5_col8" class="da

# %%
save_model(best_model, 'best_churn_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['tenure', 'MonthlyCharges',
#                                               'TotalCharges'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,...
#                                                                handle_unknown='value',
#                                                                hierarchy=None,
#                                                                min_samples_leaf=20,
#                                                                return_df=True,
#                                                                smoothing=10,
#                                                                verbose=0))),
#                  ('trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=42,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'best_churn_model.pkl')

# %%
best_model
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
df = pd.read_csv(r'C:\Users\Barsha\Downloads\MSDS\Week 2\churn_data.csv')

# %%
df.iloc[-2:-1]
# Out:
#       customerID  tenure PhoneService        Contract PaymentMethod  \
# 7041  8361-LTMKD       4          Yes  Month-to-month  Mailed check
#
#       MonthlyCharges  TotalCharges Churn
# 7041            74.4         306.6   Yes

# %%
predict_model(best_model, df.iloc[-2:-1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_60ec7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60ec7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_60ec7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_60ec7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_60ec7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_60ec7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_60ec7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_60ec7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_60ec7_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60ec7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60ec7_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_60ec7_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_60ec7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_60ec7_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_60ec7_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_60ec7_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_60ec7_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_60ec7_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#       customerID  tenure PhoneService        Contract PaymentMethod  \
# 7041  8361-LTMKD       4          Yes  Month-to-month  Mailed check
#
#       MonthlyCharges  TotalCharges Churn prediction_label  prediction_score
# 7041       74.400002    306.600006   Yes               No            0.6799

# %%
save_model(best_model, 'XGBoost')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['tenure', 'MonthlyCharges',
#                                               'TotalCharges'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,...
#                                                                handle_unknown='value',
#                                                                hierarchy=None,
#                                                                min_samples_leaf=20,
#                                                                return_df=True,
#                                                                smoothing=10,
#                                                                verbose=0))),
#                  ('trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=42,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'XGBoost.pkl')

# %%
import pickle
with open('XGBoost.pk', 'wb') as f:
    pickle.dump(best_model, f)

# %%
with open('XGBoost.pk', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
loaded_lda = load_model('XGBoost')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_data=df.iloc[-2:-1]

# %%
predict_model(loaded_lda, new_data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_51dc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51dc8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_51dc8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_51dc8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_51dc8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_51dc8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_51dc8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_51dc8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_51dc8_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51dc8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51dc8_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_51dc8_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_51dc8_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_51dc8_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_51dc8_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_51dc8_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_51dc8_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_51dc8_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#       customerID  tenure PhoneService        Contract PaymentMethod  \
# 7041  8361-LTMKD       4          Yes  Month-to-month  Mailed check
#
#       MonthlyCharges  TotalCharges Churn prediction_label  prediction_score
# 7041       74.400002    306.600006   Yes               No            0.6799

# %%
from IPython.display import Code

Code('predict_churn.py')
# Out:
# predict_churn.py

# %%
def load_data(filepath):
    """
    Loads churn data into a DataFrame from a string filepath.
    """
    df = pd.read_csv(filepath, index_col='CustomerID')  # Adjust index_col if necessary
    return df

def make_predictions(df):
    # Placeholder for the function that makes predictions
    # Replace this with your model prediction code
    predictions = df.copy()  # Example; replace with actual prediction logic
    predictions['Churn_Prob'] = 0.5  # Dummy probabilities; replace with actual predictions
    return predictions[['CustomerID', 'Churn_Prob']]

if __name__ == "__main__":
    # Update this path with the correct location of your new_predict_churn.csv file
    df = load_data(r'C:\Users\Barsha\Downloads\MSDS\Week 2\new_predict_churn.csv')  # Adjust this path
    predictions = make_predictions(df)
    print('Predictions:', predictions)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[54], line 17
#      13     return predictions[['CustomerID', 'Churn_Prob']]
#      15 if __name__ == "__main__":
#      16     # Update this path with the correct location of your new_predict_churn.csv file
# ---> 17     df = load_data(r'C:\Users\Barsha\Downloads\MSDS\Week 2\new_predict_churn.csv')  # Adjust this path
#      18     predictions = make_predictions(df)
#      19     print('Predictions:', predictions)
#
# Cell In[54], line 5, in load_data(filepath)
#       1 def load_data(filepath):
#       2     """
#       3     Loads churn data into a DataFrame from a string filepath.
#       4     """
# ----> 5     df = pd.read_csv(filepath, index_col='CustomerID')  # Adjust index_col if necessary
#       6     return df
#
# File c:\Users\Barsha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Barsha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\Barsha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Barsha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\Barsha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Barsha\\Downloads\\MSDS\\Week 2\\new_predict_churn.csv'

# %%
# %run predict_diabetes.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\Downloads\predict_diabetes.py:22
#      18     return predictions
#      21 if __name__ == "__main__":
# ---> 22     df = load_data('new_diabetes_data.csv')
#      23     predictions = make_predictions(df)
#      24     print('predictions:')
#
# File ~\Downloads\predict_diabetes.py:8, in load_data(filepath)
#       4 def load_data(filepath):
#       5     """
#       6     Loads diabetes data into a DataFrame from a string filepath.
#       7     """
# ----> 8     df = pd.read_csv(filepath, index_col='Patient number')
#       9     return df
#
# File c:\Users\Barsha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Barsha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\Barsha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Barsha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\Barsha\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'new_diabetes_data.csv'

# %% [markdown]
# ## Summary
#
# In this assignment, I used PyCaret to analyze churn data and determine the best machine learning model for predicting customer churn.
#
# 1. **Data Preparation**: Loaded the churn data and set it up in PyCaret.
# 2. **Model Comparison**: Compared multiple models and selected the best one based on the AUC metric.
# 3. **Model Saving**: The selected model was saved for future predictions.
# 4. **Prediction Script**: Developed a Python script that loads new data and predicts churn probabilities.
# 5. **Testing**: Successfully tested the prediction module with new data, returning the probability of churn for each customer.
#
# Overall, this exercise demonstrated the effective use of automated machine learning tools to streamline the model selection and prediction process.
